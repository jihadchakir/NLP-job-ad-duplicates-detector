# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import gensim
import gensim.downloader as api
import nltk
from nltk.tokenize import word_tokenize
import spacy
from hashlib import md5

# %%
nlp = spacy.load('fr_core_news_lg')

# %%
data_org = pd.read_csv("job_data.csv")

# %%
text_elements = data_org['Title'].tolist()
similarty_matrix = pd.DataFrame(index=text_elements, columns=text_elements)

# %%
class Token:
    def __init__(self, hash_list, weight):
        self.hash_list = hash_list
        self.weight = weight

# %%
data_hash = pd.read_csv("final_jobs_data.csv")

# %%
def md5Hash(token):
    h = bin(int(md5(token).hexdigest(), 16))
    return h[2:]

# %%
def hash_threshold(token_dict, fp_len):
    sum_hash = [0] * fp_len
    for _, token in token_dict.items():
        sum_hash = [ x + token.weight * y for x, y in zip(sum_hash, token.hash_list)]

    # apply binary threshold
    for i, ft in enumerate(sum_hash):
        if ft > 0:
            sum_hash[i] = 1
        else:
            sum_hash[i] = 0
    return sum_hash

# %%
def binconv(fp, fp_len):
    vec = [1] * fp_len
    for indx, b in enumerate(fp):
        if b == '0':
            vec[indx] = -1
    return vec

# %%
def calc_weights(terms, fp_len):
    term_dict = {}
    for term in terms:
        # get weights
        if term not in term_dict:
            fp_hash = md5Hash(term.encode(encoding = 'UTF-8', errors = 'strict')).zfill(fp_len)
            fp_hash_list = binconv(fp_hash, fp_len)
            token = Token(fp_hash_list, 0)
            term_dict[term] = token
        term_dict[term].weight += 1
    return term_dict

# %%
def simhash(doc, fp_len):
    tokens = tokenize(doc)
    token_dict = calc_weights(tokens, fp_len)
    fp_hash_list = hash_threshold(token_dict, fp_len)
    fp_hast_str =  ''.join(str(v) for v in fp_hash_list)
    return fp_hast_str

# %%
def tokenize(data_in):
    tmp = []
    for j in data_in:
        doc = nlp(j)
        for token in doc:
            token = token.lemma_
            tmp.append(token)
    return tmp

# %%
fp_len = 128

# %%
data_trans = data_hash.transpose()
data_trans[1]
# Out:
# Title                                      area manager casablanca maroc
# Description            communication publicité rp marketing secteur d...
# Experience                                                        3 5 an
# School level                                   bac plus 5 minimum master
# Contract Type                                                        cdi
# Teleworking                                                          non
# Deadline                                                      18 09 2023
# Entreprise             entreprise 20 an orchestrer spécialiste mode e...
# Post information       poste chercher compte un area manager mission ...
# Profile information    profil rechercher bacplus 3 plus 5 marketing m...
# Personality            organisation flexibilité ambition extraversion...
# Name: 1, dtype: object

# %%
tokens=[]
for i in range(1231):
    token = tokenize(data_trans[i])
    tokens.append(token)

# %%
token_dict = []
for i in range(len(tokens)):
    token_d = calc_weights(tokens[i], fp_len)
    token_dict.append(token_d)

# %%
fp_hash_list=[]
for i in range(1231):
    hashs = hash_threshold(token_dict[i], fp_len)
    fp_hash_list.append(hashs)

# %%
fp_hast_str_list = []
for i in range(1231):
    fp_hast_str =  ''.join(str(v) for v in fp_hash_list[i])
    fp_hast_str_list.append(fp_hast_str)

# %%
print(fp_hast_str_list)
# Out:
# ['11101101111010111000010101101010000011100000010111100111100111100110010011001011000111000111001011100010001101010110001010111100', '11000110100010110101000101011110101011010000100001100000110110011111011010110001011010111101000111100110000101010001101001110000', '11010110110010011100010100101100001001010000001000100000111110010110001001010001000011110000110111101101001100111101010101110100', '11110011111010001000100101011110100011000000010001000110001100110111000010101000101110110001000011100011111001010010010010010100', '11010000100110000100100100001100101011000001010001100001111100100110111000111101011111110110000111100100010101010100011000101000', '10110110011100100000110001101101000011111111001101101101100111110111111110001001100101010101000001101111001100010001101100101000', '10110101100010101100000110101100000011010001000000100000011010111111011110110110001100010101111111001001101011010100111110101101', '01010111100010010100110101011100001011010001000001100000100110100110011110110001010111111110000111100110000100000101111101100000', '10101110000110001100000100001100100110110101000000110100111111010110101110101011000101010101101011101110111100010101011001101000', '11100001011010000000110101001100100011111100011111000100010101010100101111111001100101010100010011100010011010110100011010101100', '10110001110111011000110100000011010011000010110110101000111100010001110010001101000011010100010011001001011100110111011101111001', '11100001111110100000110001100111101111001010000111100101010010110100111110101001001000010110001011010011011100000110000000101100', '11110010011110111100010100000100000111010101001100100101001111011111111110101111100001111111000000101111001110100111010100101000', '10110111110101010001110110001111010001011010110101101111111110010001111010001101100011010100010011001011011001110110011001111001', '00100111111011000000100111101111100011111100110111111000011111000011111010001101101001000111001001000011011101110110011101101101', '11110100111011010101100000110110101010010001100100100101010011010100101111110011001101010101001011101010101000000101011010101011', '10010111110111000000110101001111110011111010110101111100110110010011100010001101100010010100011101001101011001110100011001110101', '11111011110010111010100101001101000011000000000001010111001110111101000010011110101100111000001011100011101001010011010010110101', '10110011100001001000110101100011010110100000110100101111111110010011001110001111000010010100011001001001011001110110011000111000', '11110010110010001000100101000101100011000000000000000011000110110111001110001110101000000000000011100001101000110111011000111101', '11100111101100110100001101100110000111000100010100110101000000111010001110110101101110011100111011101111111000110001111000101110', '11101111111010101010100100000000101011000100000011110011100101000100010010101001101101111111000011100101011001010000000010100010', '11101010000010101000110101001110101010010010010010010000101111010100011110110001100101111101110011100001000100010011010010110100', '11110101101110111001000101001101100010001100100010101001011110011100010110111010101001110111100011001110101000110111011000101100', '01011111111110101000110101101110110011010001010101010101110101010110111110000001000111100111111110011000001100010011010111011100', '01110011111110101000110101001100001011110101010001000000110101111000111000101101010001010110111010100111011010010000111100100000', '11101011011010101100000101010110100011010100000111010010100101010101011110011011101101111111010111000101010100010101000000100000', '11100011011110100100110101101100101010000100010110110001000111111110011010101100001001110100101100101101000100010101000001101011', '11100000010010100111110101101001010001010000000100100101001111111100101100111001110111110101000011100011001111110010100010110100', '11100001111110000100100101001001000011100101010111010111010100110101010110011110001111100001110010100010101001110100010111101000', '11101001101000111100100101001110000111 ...

# %%
tokens[:10]
# Out:
# [['développeur',
#   'full',
#   'stack',
#   'php',
#   'casablanca',
#   'maroc',
#   'informatique',
#   'electroniqu',
#   'télécom',
#   'réseau',
#   'secteur',
#   'informatique',
#   'service',
#   '1',
#   'an',
#   '1',
#   '3',
#   'an',
#   'bac',
#   'plus',
#   '2',
#   'minimum',
#   'master',
#   'ecole',
#   'ingénieur',
#   'cdi',
#   'hybride',
#   '18',
#   '09',
#   '2023',
#   'entreprise',
#   'heure',
#   'f',
#   'associat',
#   '10',
#   'important',
#   'cabinet',
#   'recrutement',
#   'maroc',
#   'recruter',
#   'partenaire',
#   '10',
#   'an',
#   'heure',
#   'f',
#   'associate',
#   'accompagner',
#   'partenair',
#   'recrutement',
#   'recherche',
#   'meilleur',
#   'profil',
#   'jusqu',
#   "'",
#   'intégration',
#   'candidat',
#   'choisir',
#   'cabinet',
#   'recrutement',
#   'généraliste',
#   'intervenir',
#   'secteur',
#   'activité',
#   'typ',
#   'poste',
#   'auprès',
#   'entreprise',
#   'taille',
#   'grand',
#   'groupe',
#   'international',
#   'eti',
#   'pme',
#   'local',
#   'qualité',
#   'exprimer',
#   'travers',
#   'méthodologie',
#   'résultat',
#   'tal',
#   'confirmation',
#   'candidat',
#   '95',
#   'pourcent',
#   'acquisition',
#   'talent',
#   'jamais',
#   'bien',
#   'porter',
#   'nom',
#   'info',
#   'ici',
#   'www',
#   'hf',
#   'associates',
#   'com',
#   'poste',
#   'participer',
#   'développement',
#   'maintenance',
#   'application',
#   'web',
#   'baser',
#   'php',
#   'concevoir',
#   'coder',
#   'tester',
#   'fonctionnalité',
#   'nouveau',
#   'exister',
#   'collaborer',
#   'équipe',
#   'multidisciplinaire',
#   'résoudre',
#   'problème',
#   'technique',
#   'assurer',
#   'qualité',
#   'code',
#   'effectuer',
#   'test',
#   'régulier',
#   'garantir',
#   'performance',
#   'optimal',
#   'meilleur',
#   'pratique',
#   'développement',
#   'norme',
#   'industrie',
#   'profil',
#   'rechercher',
#   'expérience',
#   'avérer',
#   'développement',
#   'web',
#   'php',
#   'moins1',
#   'année',
#   'expérience',
#   'maîtri',
#   'langage',
#   'programmation',
#   'front',
#   'end',
#   'connaissance',
#   'frameworks',
#   'php',
#   'expérience',
#   'création',
#   'utilisation',
#   'base',
#   'donner',
#   'sql',
#   'familiarité',
#   'système',
#   'contrôle',
#   'version',
#   'capacité',
#   'travailler',
#   'équipe',
#   'communiquer',
#   'efficacement',
#   'portfolio',
#   'exemple',
#   'projet',
#   'précédent',
#   'être',
#   'passionner',
#   'développement',
#   'web',
#   'aimer',
#   'relever',
#   'défi',
#   'technique',
#   'souhaiter',
#   'faire',
#   'partie',
#   'entreprendre',
#   'plein',
#   'croissance',
#   'être',
#   'ravir',
#   'recevoir',
#   'candidature',
#   'recherche',
#   'nouveauté',
#   'ambition',
#   'besoin',
#   'réflexion',
#   'besoin',
#   'autonomie',
#   'implication',
#   'travail',
#   'recherche',
#   'nouveauté',
#   'ambition',
#   'besoin',
#   'réflexion',
#   'besoin',
#   'autonomie',
#   'implication',
#   'travail'],
#  ['area',
#   'manager',
#   'casablanca',
#   'maroc',
#   'communication',
#   'publicité',
#   'rp',
#   'marketing',
#   'secteur',
#   'distribution',
#   'textile',
#   'cuir',
#   '3',
#   '5',
#   'an',
#   'bac',
#   'plus',
#   '5',
#   'minimum',
#   'master',
#   'cdi',
#   'non',
#   '18',
#   '09',
#   '2023',
#   'entreprise',
#   '20',
#   'an',
#   'orchestrer',
#   'spécialiste',
#   'mode',
#   'enfant',
#   'puéricultur',
#   'franc',
#   'maroc',
#   'international',
#   'orchestrer',
#   'distinguer',
#   'marché',
#   'mettre',
#   'place',
#   'carte',
#   'club',
#   'concept',
#   'on',
#   'shopping',
#   'réunir',
#   'toit',
#   'bébé',
#   'enfant',
#   "aujourd'hui",
#   'orchestrer',
#   'offrir',
#   'large',
#   'choix',
#   'textile',
#   '100',
#   'nouveauté',
#   'mode',
#   'enfant',
#   'semaine',
#   '7000',
#   'modèle',
#   'vêtement',
#   'an',
#   'orchestrer',
#   'distribuer',
#   'grand',
#   'marque',
#   'puériculture',
#   '10',
#   '000',
#   'référence',
#   'poursuivre',
#   'développement',
#   'marque',
#   'propre',
#   'prémaman',
#   'babycar',
#   'tamboor',
#   'orchestrer',
#   'maroc',
#   'distribuer',
#   'marque',
#   'puériculture',
#   'exclusivité',
#   'joie',
#   'jané',
#   'graco',
#   'becool',
#   'nuna',
#   'large',
#   'choix',
#   'marque',
#   'groupe',
#   'attacher',
#   'faire',
#   'progresser',
#   'équipe',
#   'valorisation',
#   'promotion',
#   'interne',
#   'ambiance',
#   'entrepreneurial',
#   'projet',
#   'innovant',
#   'stratégique',
#   'cœur',
#   'journée',
#   'travail',
#   'poste',
#   'chercher',
#   'compte',
#   'un',
#   'area',
#   'manager',
#   'mission',
#   'vendre',
#   'promouvoir',
#   'article',
#   'magasin',
#   'accueillir',
#   'conseiller',
#   'client',
#   'contrôler',
#   'mettre',
#   'rayon',
#   'article',
#   'manquer',
#   'réassort',
#   'exposer',
#   'marchandise',
#   'magasin',
#   'merchandising',
#   'développer',
#   'chiffre',
#   'affaire',
#   'zone',
#   'attentif',
#   'marg',
#   'contribuer',
#   'renforcer',
#   'notoriété',
#   'marque',
#   'auprès',
#   'consommateur',
#   'travers',
#   'action',
#   'marketing',
#   'promotionnel',
#   'définir',
#   'plan',
#   'action',
#   'commercial',
#   'annuel',
#   'fonction',
#   'besoin',
#   'ville',
#   'participer',
#   'lancement',
#   'nouveau',
#   'produit',
#   'contrôler',
#   'prévision',
#   'vent',
#   'travailler',
#   'étroite',
#   'collaboration',
#   'service',
#   'approvisionnement',
#   'marketing',
#   'service',
#   'achat',
#   'gérer',
#   'budget',
#   'zone',
#   'elaborer',
#   'piloter',
#   'stratégie',
#   'commercial',
#   'périmètre',
#   'plan',
#   'action',
#   'commercial',
#   'politique',
#   'référencement',
#   '…',
#   'veiller',
#   'respect',
#   'image',
#   'marque',
#   'action',
#   'quotidien',
#   'assurer',
#   'suivre',
#   'concurrence',
#   'veille',
#   'marché',
#   'participer',
#   'amélioration',
#   'continuer',
#   'point',
#   'vent',
#   'participer',
#   'inventaire',
#   'mettre',
#   'place',
#   'tableau',
#   'bord',
#   'objectif',
#   'point',
#   'vent',
#   'assurer',
#   'croissance',
#   'profil',
#   'rechercher',
#   'bacplu',
#   '3',
#   'plus',
#   '5',
#   'marketing',
#   'management',
#   'communication',
#   'digital',
#   'maîtriser',
#   'logiciel',
#   'contenu',
#   'web',
#   'niveau',
#   'expérience',
#   '3',
#   '5',
#   'an',
#   'bon',
#   'maîtrise',
#   'langue',
#   'français',
#   'bon',
#   'connaissance',
#   'social',
#   'média',
#   'savoir',
#   'détecter',
#   'tendance',
#   'organisation',
#   'flexibilité',
#   'ambition',
#   'extraversion',
#   'recherche',
#   'nouveauté',
#   'organisation',
#   'flexibilité',
#   'ambition',
#   'extraversion',
#   'recherche',
#   'nouveauté'],
#  ['stagiaire',
#   'marketing',
#   'casablanca',
#   'maroc',
#   'marketing',
#   'secteur',
#   'communication',
#   'evénementiel',
#   '1',
#   'an',
#   'bac',
#   'plus',
#   '3',
#   'minimum',
#   'université',
#   'cdi',
#   'non',
#   '18',
#   '09',
#   '2023',
#   'entreprise',
#   '20',
#   'an',
#   'orchestrer',
#   'spécialiste',
#   'mode',
#   'enfant',
#   'puéricultur',
#   'franc',
#   'maroc',
#   'international',
#   'orchestrer',
#   'distinguer',
#   'marché',
#   'mettre',
#   'place',
#   'carte',
#   'club',
#   'concept',
#   'on',
#   'shopping',
#   'réunir',
#   'toit',
#   'bébé',
#   'enfant',
#   "aujourd'hui",
#   'orchestrer',
#   'offrir',
#   'large',
#   'choix',
#   'textile',
#   '100',
#   'nouveauté',
#   'mode',
#   'enfant',
#   'semaine',
#   '7000',
#   'modèle',
#   'vêtement',
#   'an',
#   'orchestrer',
#   'distribuer',
#   'grand',
#   'marque',
#   'puériculture',
#   '10',
#   '000',
#   'référence',
#   'poursuivre',
#   'développement',
#   'marque',
#   'propre',
#   'prémaman',
#   'babycar',
#   'tamboor',
#   'orchestrer',
#   'maroc',
#   'distribuer',
#   'marque',
#   'puériculture',
#   'exclusivité',
#   'joie',
#   'jané',
#   'graco',
#   'becool',
#   'nuna',
#   'large',
#   'choix',
#   'marque',
#   'groupe',
#   'attacher',
#   'faire',
#   'progresser',
#   'équipe',
#   'valorisation',
#   'promotion',
#   'interne',
#   'ambiance',
#   'entrepreneurial',
#   'projet',
#   'innovant',
#   'stratégique',
#   'cœur',
#   'journée',
#   'travail',
#   'poste',
#   'recherchon',
#   'un',
#   'stagiaire',
#   'marketing',
#   'rejoindre',
#   'équipe',
#   'responsabilité',
#   'inclure',
#   'création',
#   'contenu',
#   'réseau',
#   'social',
#   'site',
#   'web',
#   'participation',
#   'organisation',
#   'événement',
#   'recherche',
#   'partenariat',
#   'collaboration',
#   'participation',
#   'conception',
#   'campagne',
#   'publicitaire',
#   'stage',
#   'idéal',
#   'étudiant',
#   'marketing',
#   'communication',
#   'commerce',
#   'souhaiter',
#   'développer',
#   'compétence',
#   'professionnel',
#   'acquérir',
#   'expérience',
#   'pratique',
#   'environnement',
#   'professionnel',
#   'stimuler',
#   'stagiaire',
#   'marketing',
#   'communication',
#   'avoir',
#   'opportunité',
#   'mettre',
#   'pratique',
#   'connaissance',
#   'théorique',
#   'développer',
#   'nouveau',
#   'compétence',
#   'travailler',
#   'équipe',
#   'expérimenter',
#   'être',
#   'impliquer',
#   'e',
#   'étape',
#   'mettre',
#   'place',
#   'campagne',
#   'marketing',
#   'planification',
#   'exécution',
#   'passer',
#   'analyse',
#   'résultat',
#   'pouvoir',
#   'participer',
#   'élaboration',
#   'stratégie',
#   'communication',
#   'global',
#   'entreprise',
#   'avoir',
#   'opportunité',
#   'travailler',
#   'projet',
#   'concret',
#   'voir',
#   'immédiatement',
#   'résultat',
#   'effort',
#   'marketing',
#   'prendre',
#   'photo',
#   'vidéo',
#   'publication',
#   'réseau',
#   'proposer',
#   'idée',
#   'contenir',
#   'original',
#   'réalisation',
#   'stratégie',
#   'communication',
#   'réseal',
#   'assister',
#   'shooting',
#   'évènement',
#   'marketing',
#   'présence',
#   'requérir',
#   'profil',
#   'rechercher',
#   'prérequis',
#   'formation',
#   'digital',
#   'marketing',
#   'savoir',
#   'utiliser',
#   'inshot',
#   'capcut',
#   'prendre',
#   'vidéo',
#   'photo',
#   'créer',
#   'contenu',
#   'chaleureux',
#   'accueillir',
#   'énergétique',
#   'enthousiaste',
#   'fun',
#   'communiquer',
#   'manière',
#   'clair',
#   'français',
#   'fiable',
#   'flexible',
#   'fort',
#   'capacité',
#   'résoudre',
#   'problème',
#   'organisation',
#   'flexibilité',
#   'ambition',
#   'extraversion',
#   'recherche',
#   'nouveauté',
#   'organisation',
#   'flexibilité',
#   'ambition',
#   'extraversion',
#   'recherche',
#   'nouveauté'],
#  ['support',
#   'it',
#   'sénior',
#   'plus',
#   '5',
#   'an',
#   'expérience',
#   'rabat',
#   'maroc',
#   'informatique',
#   'electroniqu',
#   'secteur',
#   'informatique',
#   '5',
#   '10',
#   'an',
#   'bac',
#   'plus',
#   '2',
#   'minimum',
#   'formation',
#   'professionnel',
#   'formation',
#   'spécialiser',
#   'cdi',
#   'non',
#   '18',
#   '09',
#   '2023',
#   'entreprise',
#   'xpertize',
#   'bureau',
#   'recrutement',
#   'unique',
#   'genre',
#   'offrir',
#   'approche',
#   '360',
#   'degré',
#   'client',
#   'but',
#   'identifier',
#   'meilleur',
#   'candidat',
#   'marché',
#   'être',
#   'activement',
#   'passivement',
#   'recherche',
#   'nouveau',
#   'opportunité',
#   'xpertize',
#   'combine',
#   'succès',
#   'manière',
#   'ouvertement',
#   'afficher',
#   'head',
#   'hunting',
#   'approche',
#   'candidat',
#   'fonction',
#   'actuel',
#   'social',
#   'hunting',
#   'approche',
#   'indirect',
#   'candidat',
#   'exploitation',
#   'intensif',
#   'réseau',
#   'social',
#   'priver',
#   'professionnel',
#   'combinaison',
#   'unique',
#   'appuyer',
#   'part',
#   'méthodologie',
#   'traditionnel',
#   'recherche',
#   'candidat',
#   'part',
#   'puissance',
#   'offrir',
#   'réseau',
#   'social',
#   'xpertize',
#   'optimiser',
#   'phase',
#   'identification',
#   'candidat',
#   'concentrer',
#   'analyse',
#   'compétence',
#   'méthodologie',
#   'unique',
#   'impact',
#   'direct',
#   'qualité',
#   'candidat',
#   'identifier',
#   'part',
#   'rapiditer',
#   'engagement',
#   'candidat',
#   'idéal',
#   'part',
#   'poste',
#   'administrer',
#   'maintenir',
#   'réseau',
#   'client',
#   'parer',
#   'feu',
#   'commutateur',
#   'routeur',
#   'etc',
#   'assurer',
#   'disponibilité',
#   'sécurité',
#   'réseau',
#   'effectuer',
#   'tâcher',
#   'configuration',
#   'surveillance',
#   'maintenanc',
#   'régulier',
#   'prendre',
#   'charge',
#   'résoudre',
#   'incident',
#   'informatique',
#   'niveau',
#   '1',
#   'signaler',
#   'utilisateur',
#   'fournir',
#   'support',
#   'technique',
#   'approprié',
#   'collaborer',
#   'équipe',
#   'interne',
#   'résoudre',
#   'problème',
#   'complexe',
#   'assurer',
#   'résolution',
#   'efficace',
#   'incident',
#   'participer',
#   'planification',
#   'mettre',
#   'œuvre',
#   'projet',
#   'infrastructure',
#   'informatique',
#   'documenter',
#   'procédure',
#   'configuration',
#   'réseau',
#   'assurer',
#   'gestion',
#   'efficace',
#   'parc',
#   'profil',
#   'rechercher',
#   'diplôme',
#   'niveau',
#   'bacplus',
#   '3',
#   'administration',
#   'système',
#   'information',
#   'domaine',
#   'connexe',
#   'expérience',
#   'professionnel',
#   '5',
#   '6',
#   'an',
#   'administration',
#   'parc',
#   'gestion',
#   'réseau',
#   'parer',
#   'feu',
#   'commutateur',
#   'solide',
#   'compétence',
#   'résolution',
#   'problème',
#   'dépannage',
#   'incident',
#   'informatique',
#   'niveau',
#   '1',
#   'connaissance',
#   'approfondie',
#   'protocole',
#   'réseau',
#   'parer',
#   'feu',
#   'commutateur',
#   'technologie',
#   'réseau',
#   'capacité',
#   'travailler',
#   'manière',
#   'autonome',
#   'gérer',
#   'tâche',
#   'simultanément',
#   'excellent',
#   'compétence',
#   'communication',
#   'collaboration',
#   'travailler',
#   'efficacement',
#   'utilisateur',
#   'équipe',
#   'interne',
#   'recherche',
#   'nouveauté',
#   'ambition',
#   'besoin',
#   'réflexion',
#   'besoin',
#   'autonomie',
#   'implication',
#   'travail',
#   'recherche',
#   'nouveauté',
#   'ambition',
#   'besoin',
#   'réflexion',
#   'besoin',
#   'autonomie',
#   'implication',
#   'travail'],
#  ['agent',
#   'logistique',
#   'casablanca',
#   'maroc',
#   'logistique',
#   'transport',
#   'métier',
#   'secteur',
#   'transport',
#   'messagerie',
#   'logistique',
#   '1',
#   '3',
#   'an',
#   'bac',
#   'plus',
#   '2',
#   'minimum',
#   'formation',
#   'professionnel',
#   'formation',
#   'spécialiser',
#   'cdi',
#   'non',
#   '18',
#   '09',
#   '2023',
#   'entreprise',
#   '20',
#   'an',
#   'orchestrer',
#   'spécialiste',
#   'mode',
#   'enfant',
#   'puéricultur',
#   'franc',
#   'maroc',
#   'international',
#   'orchestrer',
#   'distinguer',
#   'marché',
#   'mettre',
#   'place',
#   'carte',
#   'club',
#   'concept',
#   'on',
#   'shopping',
#   'réunir',
#   'toit',
#   'bébé',
#   'enfant',
#   "aujourd'hui",
#   'orchestrer',
#   'offrir',
#   'large',
#   'choix',
#   'textile',
#   '100',
#   'nouveauté',
#   'mode',
#   'enfant',
#   'semaine',
#   '7000',
#   'modèle',
#   'vêtement',
#   'an',
#   'orchestrer',
#   'distribuer',
#   'grand',
#   'marque',
#   'puériculture',
#   '10',
#   '000',
#   'référence',
#   'poursuivre',
#   'développement',
#   'marque',
#   'propre',
#   'prémaman',
#   'babycar',
#   'tamboor',
#   'orchestrer',
#   'maroc',
#   'distribuer',
#   'marque',
#   'puériculture',
#   'exclusivité',
#   'joie',
#   'jané',
#   'graco',
#   'becool',
#   'nuna',
#   'large',
#   'choix',
#   'marque',
#   'groupe',
#   'attacher',
#   'faire',
#   'progresser',
#   'équipe',
#   'valorisation',
#   'promotion',
#   'interne',
#   'ambiance',
#   'entrepreneurial',
#   'projet',
#   'innovant',
#   'stratégique',
#   'cœur',
#   'journée',
#   'travail',
#   'poste',
#   'chercher',
#   'compte',
#   'agent',
#   'logistique',
#   'expérience',
#   'remarquable',
#   'domaine',
#   'amener',
#   'participer',
#   'gestion',
#   'flux',
#   'marchandise',
#   'assurer',
#   'réception',
#   'stockage',
#   'préparation',
#   'marchandis',
#   'expédition',
#   'préparer',
#   'commande',
#   'rédiger',
#   'vérifier',
#   'document',
#   'expédition',
#   'assurer',
#   'bon',
#   'condition',
#   'expédition',
#   'adapter',
#   'produit',
#   'réceptionner',
#   'produit',
#   'vérifier',
#   'état',
#   'conformité',
#   'organiser',
#   'magasinage',
#   'stockage',
#   'produire',
#   'évolution',
#   'niveau',
#   'stock',
#   'logiciel',
#   'profil',
#   'rechercher',
#   'expérience',
#   'requérir',
#   '2',
#   'an',
#   'minimum',
#   'technique',
#   'préparation',
#   'conditionnement',
#   'produire',
#   'commande',
#   'rigueur',
#   'précision',
#   'sentir',
#   'priorité',
#   'organisation',
#   'travailler',
#   'équipe',
#   'respect',
#   'régler',
#   'besoin',
#   'action',
#   'implication',
#   'travail',
#   'organisation',
#   'respect',
#   'régler',
#   'besoin',
#   'action',
#   'implication',
#   'travail',
#   'organisation'],
#  ['devenir',
#   'consulter',
#   'rejoindre',
#   'leyton',
#   'offrir',
#   'ouvert',
#   'ingénieur',
#   'docteur',
#   'doctorer',
#   'informatique',
#   'casablanca',
#   'maroc',
#   'informatique',
#   'electroniqu',
#   'multimédia',
#   'internet',
#   'secteur',
#   'informatique',
#   'telecom',
#   '3',
#   '5',
#   'an',
#   'bac',
#   'plus',
#   '5',
#   'minimum',
#   'ecole',
#   'ingénieur',
#   'cdi',
#   'hybride',
#   '26',
#   '08',
#   '2023',
#   'entreprise',
#   'dire',
#   "aujourd'hui",
#   'combiner',
#   'innovation',
#   'performanc',
#   'durabilité',
#   'plaisir',
#   'rejoindre',
#   'leyton',
#   'cabinet',
#   'conseil',
#   'international',
#   'dédier',
#   'amélioration',
#   'performance',
#   'économique',
#   'social',
#   'environnemental',
#   'organisation',
#   'consulter',
#   'expert',
#   'technique',
#   'apporter',
#   'solution',
#   'concret',
#   'contribuer',
#   'progrès',
#   'durable',
#   'client',
#   'groupe',
#   'compte',
#   '3000',
#   'collaborateur',
#   'répartir',
#   '16',
#   'pays',
#   'maroc',
#   'leyton',
#   'compte',
#   '750',
#   'collaborateur',
#   'distinguer',
#   'positionnement',
#   'singulier',
#   'fort',
#   'valeur',
#   'ajouter',
#   'métier',
#   'conseil',
#   'financement',
#   'innovation',
#   'transition',
#   'écologique',
#   'amélioration',
#   'performance',
#   'opérationnel',
#   'entreprise',
#   'cher',
#   'ingénieur',
#   'doctorant',
#   'docteur',
#   'informatique',
#   'être',
#   'vous',
#   'prêt',
#   'plonger',
#   'univers',
#   'innovation',
#   'technologique',
#   'façonner',
#   'monde',
#   'numérique',
#   'demain',
#   'oui',
#   'saisir',
#   'opportunité',
#   'leyton',
#   'être',
#   'recherche',
#   'talent',
#   'exceptionnel',
#   'rejoindre',
#   'équipe',
#   'consulter',
#   'r',
#   'd',
#   'ict',
#   'consulter',
#   'être',
#   'expert',
#   'technique',
#   'véritable',
#   'pionnier',
#   'transformation',
#   'numérique',
#   'repousson',
#   'limite',
#   'imagination',
#   'technologique',
#   'analyser',
#   'projet',
#   'recherche',
#   'développement',
#   'innovation',
#   'client',
#   'domaine',
#   'l',
#   "'",
#   'intelligenceartificiell',
#   'cybersécurité',
#   'cloudcomputing',
#   'l',
#   "'",
#   'internetdesobjet',
#   'engager',
#   'rester',
#   'tête',
#   'peloton',
#   'anticiper',
#   'tendance',
#   'futur',
#   'poste',
#   'futur',
#   'mission',
#   'gestion',
#   'portefeuill',
#   'client',
#   'réalisation',
#   'opérationnel',
#   'mission',
#   'garantie',
#   'satisfaction',
#   'client',
#   'maitrise',
#   'composante',
#   'économique',
#   'portefeuill',
#   'ca',
#   'rentabilité',
#   'analyse',
#   'projet',
#   'r',
#   'd',
#   'innovation',
#   'client',
#   'startup',
#   'pm',
#   'eti',
#   'grand',
#   'groupe',
#   'valorisation',
#   'financier',
#   'étude',
#   'possibilité',
#   'financement',
#   'public',
#   'constitution',
#   'dossier',
#   'justification',
#   'technique',
#   'financier',
#   'accompagnement',
#   'client',
#   'étape',
#   'mission',
#   'profil',
#   'rechercher',
#   'ingénieur',
#   'docteur',
#   'doctorant',
#   'domaine',
#   'informatique',
#   'ouverture',
#   'international',
#   'terme',
#   'étude',
#   'expérience',
#   'professionnel',
#   'france',
#   'expérience',
#   'travail',
#   'pertinent',
#   'idéalement',
#   'domaine',
#   'conseil',
#   'excellent',
#   'compétence',
#   'rédaction',
#   'communication',
#   'français',
#   'esprit',
#   'analytique',
#   'curiosité',
#   'dynamisme',
#   'adaptabiliter',
#   'bon',
#   'compétence',
#   'interpersonnel',
#   'esprit',
#   'équipe',
#   'principal',
#   'facteur',
#   'réussite',
#   'différenci',
#   'environnement',
#   'travail',
#   'collaboratif',
#   'croire',
#   'fermement',
#   'innovation',
#   'naître',
#   'diversité',
#   'idée',
#   'avoir',
#   'possibilité',
#   'travailler',
#   'étroite',
#   'collaboration',
#   'expert',
#   'talentueux',
#   'horizon',
#   'permettre',
#   'élargir',
#   'compétence',
#   'repousser',
#   'propre',
#   'limite',
#   'projet',
#   'stimuler',
#   'ennuyer',
#   'jamais',
#   'travailler',
#   'projet',
#   'passionner',
#   'novateur',
#   'résoudre',
#   'réel',
#   'défi',
#   'client',
#   'jour',
#   'être',
#   'confronter',
#   'nouveau',
#   'opportunité',
#   'repousser',
#   'frontière',
#   'technologie',
#   'culture',
#   'apprentissage',
#   'continu',
#   'valoriser',
#   'développement',
#   'professionnel',
#   'investir',
#   'croissance',
#   'offrir',
#   'avantage',
#   'assurer',
#   'environnement',
#   'travail',
#   'agréable',
#   'amusant',
#   'esprit',
#   'start',
#   'up',
#   'sein',
#   'groupe',
#   'multinational',
#   'plein',
#   'croissance',
#   'diversification',
#   'projet',
#   'apprentissage',
#   'grâce',
#   'mission',
#   'point',
#   'équilibre',
#   'vie',
#   'professionnel',
#   'personnel',
#   'avantage',
#   'social',
#   'opportunité',
#   'croissance',
#   'carrière',
#   'environnement',
#   'apprentissage',
#   'continu',
#   'activité',
#   'renforcement',
#   'équipe',
#   'partenariat',
#   'santé',
#   'divertissement',
#   'joindre',
#   'vous',
#   'façonner',
#   'avenir',
#   'numérique',
#   'laisser',
#   'empreinte',
#   'histoire',
#   'technologie',
#   'recherche',
#   'nouveauté',
#   'ambition',
#   'besoin',
#   'réflexion',
#   'besoin',
#   'autonomie',
#   'implication',
#   'travail',
#   'recherche',
#   'nouveauté',
#   'ambition',
#   'besoin',
#   'réflexion',
#   'besoin',
#   'autonomie',
#   'implication',
#   'travail'],
#  ['expert',
#   'financ',
#   'digital',
#   'fintech',
#   'rabat',
#   'maroc',
#   'audit',
#   'conseil',
#   'secteur',
#   'banque',
#   'financ',
#   '3',
#   '5',
#   'an',
#   '5',
#   '10',
#   'an',
#   'bac',
#   'plus',
#   '5',
#   'minimum',
#   'master',
#   'ecole',
#   'commerce',
#   'autre',
#   'non',
#   '23',
#   '07',
#   '2023',
#   'entreprise',
#   'deutsch',
#   'gesellschaft',
#   'für',
#   'international',
#   'zusammenarbeit',
#   'giz',
#   'gmbh',
#   'prestataire',
#   'service',
#   'coopération',
#   'international',
#   'actif',
#   'niveau',
#   'mondial',
#   'présent',
#   'maroc',
#   '1975',
#   'partenair',
#   'mettre',
#   'point',
#   'solution',
#   'efficace',
#   'ouvrir',
#   'perspectif',
#   'population',
#   'améliorer',
#   'durablement',
#   'condition',
#   'vie',
#   'titre',
#   'entreprendre',
#   'fédéral',
#   'utilité',
#   'public',
#   'giz',
#   'soutenir',
#   'beaucoup',
#   'secteur',
#   'grand',
#   'nombre',
#   'client',
#   'national',
#   'international',
#   'mettre',
#   'œuvre',
#   'coopération',
#   'bilatéral',
#   'régional',
#   'international',
#   'gouvernement',
#   'marocain',
#   'allemand',
#   'définir',
#   'secteur',
#   'prioritaire',
#   'politique',
#   'coopération',
#   'constituer',
#   'base',
#   'programme',
#   'projet',
#   'énergie',
#   'renouvelable',
#   'environnement',
#   'changement',
#   'climatique',
#   'gestion',
#   'utilisation',
#   'durable',
#   'ressource',
#   'développement',
#   'économique',
#   'durable',
#   'institution',
#   'allemand',
#   'actuel',
#   'disposer',
#   'large',
#   'éventail',
#   'instrument',
#   'permettre',
#   'faire',
#   'face',
#   'grand',
#   'nombre',
#   'défi',
#   'baser',
#   'expérience',
#   'professionnel',
#   'approfondie',
#   'confiance',
#   'mutuel',
#   'coopération',
#   'morocco',
#   'allemand',
#   'constituer',
#   'pilier',
#   'paix',
#   'région',
#   'travers',
#   'projet',
#   'global',
#   'régional',
#   'bilatéral',
#   'giz',
#   'contribuer',
#   'manière',
#   'signifier',
#   'développement',
#   'durable',
#   'maroc',
#   'poste',
#   'deutsch',
#   'gesellschaft',
#   'für',
#   'international',
#   'zusammenarbeit',
#   'giz',
#   'gmbh',
#   'partenariat',
#   'ministèr',
#   'économie',
#   'finance',
#   'mef',
#   'partenair',
#   'politique',
#   'partenair',
#   'public',
#   'priver',
#   'charger',
#   'mettre',
#   'œuvre',
#   'période',
#   'juillet',
#   '2020',
#   'juin',
#   '2024',
#   'projet',
#   '«',
#   'promotion',
#   'entrepreneuriat',
#   '»',
#   'promettre',
#   'projet',
#   'promettre',
#   'giz',
#   'entreprendre',
#   'activité',
#   'travers',
#   'domaine',
#   'intervention',
#   'axe',
#   '1',
#   'amélioration',
#   'climat',
#   'affaire',
#   'condition',
#   'cadr',
#   'règlementair',
#   'administratif',
#   'conception',
#   'stratégie',
#   'consister',
#   'cibler',
#   'petit',
#   'petit',
#   'moyen',
#   'entreprise',
#   'tpm',
#   'auto',
#   'entrepreneur',
#   'ae',
#   'start',
#   'up',
#   'axe',
#   '2',
#   'coordination',
#   'amélioration',
#   'offrir',
#   'service',
#   'accompagnement',
#   '–',
#   'financier',
#   'non',
#   'financier',
#   '–',
#   'tpm',
#   'ae',
#   'start',
#   'up',
#   'axe',
#   '3',
#   'appui',
#   'création',
#   'amélioration',
#   'écosystèm',
#   'régional',
#   'appui',
#   'tpm',
#   'ae',
#   'start',
#   'up',
#   'projet',
#   'promettre',
#   'recruter',
#   'expert',
#   'financ',
#   'digital',
#   'fintech',
#   'cadre',
#   'fonction',
#   'être',
#   'responsable',
#   'mettre',
#   'œuvre',
#   'technique',
#   'organisationnel',
#   'fond',
#   'mesure',
#   'activité',
#   'relever',
#   'périmètre',
#   'sein',
#   'équipe',
#   'axe',
#   '2',
#   'projet',
#   'promettre',
#   'concertation',
#   'supérieur',
#   'r',
#   'hiérarchique',
#   'prendre',
#   'charge',
#   'tâche',
#   'lien',
#   'planification',
#   'pilotage',
#   'suivre',
#   'projet',
#   'mesure',
#   'administration',
#   'projet',
#   'apporter',
#   'contribution',
#   'technique',
#   'fonds',
#   'qualité',
#   'thématique',
#   'développement',
#   'système',
#   'financier',
#   'général',
#   'fintech',
#   'particulier',
#   'thématique',
#   'transversal',
#   'coopération',
#   'partenair',
#   'client',
#   'commettre',
#   'contribuer',
#   'réalisation',
#   'objectif',
#   'convenir',
#   'projet',
#   'promettre',
#   'donner',
#   'impulsion',
#   'poursuite',
#   'développement',
#   'stratégie',
#   'veiller',
#   'mettre',
#   'œuvre',
#   'synergie',
#   'potentiel',
#   'composante',
#   'projet',
#   'promettre',
#   'projet',
#   'giz',
#   'cluster',
#   'développement',
#   'economiqu',
#   'durable',
#   'projet',
#   'national',
#   'international',
#   'domaine',
#   'développement',
#   'système',
#   'financier',
#   'général',
#   'particulier',
#   'sein',
#   'région',
#   'intervention',
#   'promettre',
#   'assurer',
#   'coordination',
#   'partenair',
#   'partag',
#   'expérience',
#   'capitalisation',
#   'mettre',
#   'échelle',
#   'processus',
#   'développer',
#   'domaine',
#   '«',
#   'développement',
#   'système',
#   'financier',
#   '»',
#   'général',
#   '«',
#   'fintech',
#   '»',
#   'particulier',
#   'axe',
#   '2',
#   'promettre',
#   'profil',
#   'rechercher',
#   'le',
#   'le',
#   'titulaire',
#   'poste',
#   'amener',
#   'e',
#   'assurer',
#   'mise',
#   'œuvre',
#   'technique',
#   'organisationnel',
#   'mesure',
#   'activité',
#   'lier',
#   'développement',
#   'finance',
#   'innovant',
#   'digital',
#   'fintech',
#   'crowdfunding',
#   'open',
#   'banking',
#   'etc',
#   'relever',
#   'thématique',
#   '«',
#   'inclusion',
#   'financier',
#   '»',
#   'prendre',
#   'charge',
#   'tâche',
#   'lien',
#   'planification',
#   'pilotage',
#   'suivre',
#   'évaluation',
#   'communication',
#   'gestion',
#   'connaissance',
#   'mettre',
#   'échelle',
#   'administration',
#   'domaine',
#   'intervention',
#   'concertation',
#   'responsable',
#   'thématique',
#   '«',
#   'inclusion',
#   'financier',
#   '»',
#   'supérieur',
#   'hiérarchique',
#   'assurer',
#   'mise',
#   'œuvre',
#   'synergie',
#   'exister',
#   'potentiel',
#   'domaine',
#   '«',
#   'inclusion',
#   'financier',
#   '»',
#   'particulièrement',
#   'finance',
#   'innovant',
#   'digital',
#   'domaine',
#   'projet',
#   'promettre',
#   'càd',
#   'thèm',
#   'amélioration',
#   'environnement',
#   'affaire',
#   'développement',
#   'service',
#   'non',
#   'financier',
#   'appui',
#   'start',
#   'ups',
#   'structure',
#   'régional',
#   'soutien',
#   'projet',
#   'cluster',
#   'développement',
#   'économique',
#   'durable',
#   'projet',
#   'national',
#   'international',
#   'entretenir',
#   'relation',
#   'partenair',
#   'acteur',
#   'actuel',
#   'potentiel',
#   'écosystèm',
#   'finance',
#   'innovant',
#   'digital',
#   'assurer',
#   'veille',
#   'permanent',
#   'produire',
#   'note',
#   'technique',
#   'développement',
#   'finance',
#   'innovant',
#   'digital',
#   'maroc',
#   'afrique',
#   'région',
#   'mener',
#   'économie',
#   'émergent',
#   'développer',
#   'assurer',
#   'préparation',
#   'réalisation',
#   'atelier',
#   'séminaire',
#   'événement',
#   'thèm',
#   'rapport',
#   'domaine',
#   '«',
#   'développement',
#   'système',
#   'financier',
#   '»',
#   'général',
#   '«',
#   'fintech',
#   '»',
#   'particulier',
#   'axe',
#   '2',
#   'promettre',
#   'appuyer',
#   'responsable',
#   'thème',
#   '«',
#   'inclusion',
#   'financier',
#   '»',
#   'conseiller',
#   'technique',
#   'principal',
#   'rapport',
#   'envoyer',
#   'party',
#   'prendre',
#   'assurer',
#   'flux',
#   'régulier',
#   'information',
#   'pertinent',
#   'dernier',
#   'contribuer',
#   'gestion',
#   'connaissance',
#   'efficace',
#   'élaboration',
#   'support',
#   'communication',
#   'domaine',
#   '«',
#   'développement',
#   'système',
#   'financier',
#   '»',
#   'général',
#   '«',
#   'fintech',
#   '»',
#   'particulier',
#   'axe',
#   '2',
#   'promettre',
#   'qualification',
#   'compétence',
#   'expérience',
#   'requérir',
#   'titulaire',
#   'master',
#   'équivalent',
#   'domaine',
#   'financ',
#   'économie',
#   'spécialisation',
#   'mécanisme',
#   'financement',
#   'gestion',
#   'portefeuill',
#   'dater',
#   'analyst',
#   'marché',
#   'capital',
#   'expérience',
#   'minimal',
#   '3',
#   'an',
#   'fonds',
#   'investissement',
#   'établissement',
#   'financier',
#   'organisation',
#   'international',
#   'maîtris',
#   'outil',
#   'analyse',
#   'visualisation',
#   'donner',
#   'connaissance',
#   'nouveau',
#   'technologie',
#   'appliquer',
#   'finance',
#   'blockchain',
#   'intelligence',
#   'artificiel',
#   'machine',
#   'learning',
#   'chatbot',
#   'robot',
#   'advisor',
#   'mobile',
#   'payment',
#   'etc',
#   'connaissance',
#   'secteur',
#   'concerner',
#   'fintechs',
#   'insurtech',
#   'regtech',
#   'lendtech',
#   'paytech',
#   'etc',
#   'connaissance',
#   'cadr',
#   'réglementaire',
#   'risque',
#   'lier',
#   'sécurité',
#   'conformité',
#   'confidentialité',
#   'donner',
#   'connaissance',
#   'approfondie',
#   'procédure',
#   'instrument',
#   'domaine',
#   'coopération',
#   'développement',
#   'bon',
#   'connaissance',
#   'pratique',
#   'utilisation',
#   'technologie',
#   'information',
#   'communication',
#   'application',
#   'informatique',
#   'm',
#   'office',
#   'programme',
#   'base',
#   'donner',
#   'adapter',
#   'manière',
#   'actif',
#   'constructif',
#   'situation',
#   'défi',
#   'excellent',
#   'capacité',
#   'organisationnel',
#   'coordination',
#   'gestion',
#   'structuration',
#   'planification',
#   'général',
#   'travailler',
#   'manière',
#   'constructif',
#   'objectif',
#   'commun',
#   'sens',
#   'responsabilité',
#   'esprit',
#   'initiative',
#   'anticipation',
#   'autonomie',
#   'travail',
#   'doter',
#   'excellent',
#   'aptitude',
#   'relation',
#   'interpersonnel',
#   'dialogue',
#   'partenariat',
#   'coordination',
#   'négociation',
#   'communiquer',
#   'clair',
#   'structurer',
#   'écrire',
#   'oral',
#   'faire',
#   'preuve',
#   'esprit',
#   'critique',
#   'curiosité',
#   'intellectuel',
#   'maîtris',
#   'oral',
#   'écrire',
#   'langue',
#   'français',
#   'arabe',
#   'anglais',
#   'connaissance',
#   'allemand',
#   'atout',
#   'période',
#   'mettre',
#   'œuvre',
#   'projet',
#   '01',
#   '07',
#   '2020',
#   '30',
#   '06',
#   '2024',
#   'organisation',
#   'implication',
#   'travail',
#   'besoin',
#   'autonomie',
#   'extraversion',
#   'respect',
#   'régler',
#   'organisation',
#   'implication',
#   'travail',
#   'besoin',
#   'autonomie',
#   'extraversion',
#   'respect',
#   'régler'],
#  ['responsable',
#   'magasin',
#   'kenitra',
#   'maroc',
#   'administration',
#   'vent',
#   'sav',
#   'commercial',
#   'vent',
#   'export',
#   'secteur',
#   'distribution',
#   'textile',
#   'cuir',
#   '3',
#   '5',
#   'an',
#   'bac',
#   'plus',
#   '3',
#   'minimum',
#   'université',
#   'cdi',
#   'non',
#   '18',
#   '09',
#   '2023',
#   'entreprise',
#   '20',
#   'an',
#   'orchestrer',
#   'spécialiste',
#   'mode',
#   'enfant',
#   'puéricultur',
#   'franc',
#   'maroc',
#   'international',
#   'orchestrer',
#   'distinguer',
#   'marché',
#   'mettre',
#   'place',
#   'carte',
#   'club',
#   'concept',
#   'on',
#   'shopping',
#   'réunir',
#   'toit',
#   'bébé',
#   'enfant',
#   "aujourd'hui",
#   'orchestrer',
#   'offrir',
#   'large',
#   'choix',
#   'textile',
#   '100',
#   'nouveauté',
#   'mode',
#   'enfant',
#   'semaine',
#   '7000',
#   'modèle',
#   'vêtement',
#   'an',
#   'orchestrer',
#   'distribuer',
#   'grand',
#   'marque',
#   'puériculture',
#   '10',
#   '000',
#   'référence',
#   'poursuivre',
#   'développement',
#   'marque',
#   'propre',
#   'prémaman',
#   'babycar',
#   'tamboor',
#   'orchestrer',
#   'maroc',
#   'distribuer',
#   'marque',
#   'puériculture',
#   'exclusivité',
#   'joie',
#   'jané',
#   'graco',
#   'becool',
#   'nuna',
#   'large',
#   'choix',
#   'marque',
#   'groupe',
#   'attacher',
#   'faire',
#   'progresser',
#   'équipe',
#   'valorisation',
#   'promotion',
#   'interne',
#   'ambiance',
#   'entrepreneurial',
#   'projet',
#   'innovant',
#   'stratégique',
#   'cœur',
#   'journée',
#   'travail',
#   'poste',
#   'mission',
#   'consister',
#   'veiller',
#   'bon',
#   'accueil',
#   'clientèl',
#   'assurer',
#   'bon',
#   'présentation',
#   'tenue',
#   'magasin',
#   'participer',
#   'vent',
#   'côté',
#   'vendeur',
#   'respecter',
#   'concept',
#   'entreprise',
#   'consigne',
#   'merchandising',
#   'mettre',
#   'place',
#   'opération',
#   'commercial',
#   'préparer',
#   'plan',
#   'action',
#   'organiser',
#   'ouverture',
#   'fermeture',
#   'magasin',
#   'préparer',
#   'inventaire',
#   'organiser',
#   'stock',
#   'former',
#   'faire',
#   'fédérer',
#   'collaborateur',
#   'fixer',
#   'objectif',
#   'atteindre',
#   'terme',
#   'vent',
#   'chiffre',
#   'affaire',
#   'suivre',
#   'quotidien',
#   'chiffre',
#   'affaire',
#   'gérer',
#   'opération',
#   'administratif',
#   'magasin',
#   'contrôler',
#   'mouvement',
#   'caisse',
#   'opération',
#   'bancaire',
#   'analyser',
#   'indicateur',
#   'commercial',
#   'nombre',
#   'visite',
#   'progression',
#   'chiffre',
#   'affaire',
#   '…',
#   'assurer',
#   'reporting',
#   'auprès',
#   'hiérarchie',
#   'capable',
#   'communiquer',
#   'party',
#   'prendre',
#   'profil',
#   'rechercher',
#   'expérience',
#   '3',
#   'minimum',
#   'expérience',
#   'retail',
#   'expérience',
#   'vent',
#   'recherche',
#   'nouveauté',
#   'extraversion',
#   'volonté',
#   'persuasion',
#   'travail',
#   'équipe',
#   'ambition',
#   'improvisation',
#   'créativité',
#   'implication',
#   'travail',
#   'recherche',
#   'nouveauté',
#   'extraversion',
#   'volonté',
#   'persuasion',
#   'travail',
#   'équipe',
#   'ambition',
#   'improvisation',
#   'créativité',
#   'implication',
#   'travail'],
#  ['comptable',
#   'heure',
#   'f',
#   'casablanca',
#   'maroc',
#   'audit',
#   'conseil',
#   'gestion',
#   'comptabilité',
#   'finance',
#   'secteur',
#   'comptabilité',
#   'audit',
#   'offshoring',
#   'nearshoring',
#   '1',
#   '3',
#   'an',
#   'bac',
#   'plus',
#   '3',
#   'minimum',
#   'cdd',
#   'non',
#   '26',
#   '08',
#   '2023',
#   'entreprise',
#   '1902',
#   'dr',
#   'willis',
#   'heure',
#   'carrier',
#   'inventer',
#   'fabrique',
#   'climatiseur',
#   'moderne',
#   'monde',
#   'date',
#   'carrier',
#   'corporation',
#   'numéro',
#   'mondial',
#   'climatisation',
#   '4',
#   'million',
#   'unité',
#   'vendre',
#   'an',
#   'assembler',
#   '40',
#   'usine',
#   'production',
#   'installer',
#   'entretenir',
#   'continent',
#   'créer',
#   '2014',
#   'mc',
#   'fruit',
#   'joindre',
#   'venture',
#   'signer',
#   'ventec',
#   'maroc',
#   'carrier',
#   'numéro',
#   '1',
#   'mondial',
#   'domaine',
#   'froid',
#   'mc',
#   'assurer',
#   'support',
#   'technique',
#   'commercial',
#   'administratif',
#   'distance',
#   'compte',
#   'carrier',
#   'france',
#   'carrier',
#   'espagne',
#   'otis',
#   'france',
#   'chubb',
#   'france',
#   'ciat',
#   'carrier',
#   'transicold',
#   'carrier',
#   'réfrigération',
#   'société',
#   'groupe',
#   'mcs',
#   'assurer',
#   'efficienc',
#   'efficacité',
#   'traitement',
#   'demande',
#   'particulier',
#   'consultation',
#   'saisie',
#   'commande',
#   'gestion',
#   'réclamation',
#   'planification',
#   'intervention',
#   'support',
#   'technique',
#   'distance',
#   'souhaiter',
#   'révéler',
#   'potentiel',
#   'environnement',
#   'challenger',
#   'collaboratif',
#   'souhaiter',
#   'évoluer',
#   'structure',
#   'soucieux',
#   'épanouissement',
#   'satisfaction',
#   'moyen',
#   'humain',
#   'saisir',
#   'opportunité',
#   'concrétiser',
#   'idée',
#   'cœur',
#   'projet',
#   'ambitieux',
#   'envoyer',
#   'candidature',
#   'poste',
#   'cadre',
#   'développement',
#   'recruter',
#   'un',
#   'comptable',
#   'être',
#   'responsable',
#   'mission',
#   'comptabiliser',
#   'facture',
#   'format',
#   'approuver',
#   'facture',
#   'condition',
#   'strict',
#   'définir',
#   'mode',
#   'opératoire',
#   'communiquer',
#   'charger',
#   'compte',
#   'résultat',
#   'analyse',
#   'conduire',
#   'intervention',
#   'facture',
#   'correction',
#   'approbation',
#   'complexe',
#   '…',
#   'répondre',
#   'demande',
#   'détail',
#   'relance',
#   'fournisseur',
#   'client',
#   'téléphone',
#   'émail',
#   'profil',
#   'rechercher',
#   'pouvoir',
#   'faire',
#   'partie',
#   'team',
#   'mcs',
#   'formation',
#   'bacplus',
#   '2',
#   '3',
#   'comptabilité',
#   'expérience',
#   '2',
#   '3',
#   'an',
#   'qualité',
#   'comptable',
#   'bon',
#   'communication',
#   'bon',
#   'maîtrise',
#   'français',
#   'écrire',
#   'oral',
#   'force',
#   'proposition',
#   'autonomie',
#   'offrir',
#   'avoir',
#   'occasion',
#   'faire',
#   'partie',
#   'environnement',
#   'international',
#   'constant',
#   'évolution',
#   'faire',
#   'partie',
#   'équipe',
#   'amusant',
#   'esprit',
#   'favoriser',
#   'diversité',
#   'horaire',
#   'travail',
#   'administratif',
#   'équilibre',
#   'vie',
#   'professionnel',
#   'vie',
#   'priver',
#   'environnement',
#   'international',
#   'plein',
#   'expansion',
#   'environnement',
#   'apprentissage',
#   'continu',
#   'team',
#   'building',
#   'activité',
#   'etc',
#   'organisation',
#   'implication',
#   'travail',
#   'besoin',
#   'objectivité',
#   'conventionnel',
#   'ambition',
#   'travail',
#   'équipe',
#   'besoin',
#   'action',
#   'respect',
#   'régler',
#   'organisation',
#   'implication',
#   'travail',
#   'besoin',
#   'objectivité',
#   'conventionnel',
#   'ambition',
#   'travail',
#   'équipe',
#   'besoin',
#   'action',
#   'respect',
#   'régler'],
#  ['développeur',
#   'fullstack',
#   'php',
#   'laravel',
#   'freelance',
#   'cdi',
#   'casablanca',
#   'maroc',
#   'informatique',
#   'electroniqu',
#   'secteur',
#   'informatique',
#   '5',
#   '10',
#   'an',
#   'bac',
#   'plus',
#   '5',
#   'minimum',
#   'master',
#   'cdi',
#   'non',
#   '17',
#   '09',
#   '2023',
#   'entreprise',
#   'e',
#   'solution',
#   'entreprise',
#   'service',
#   'conseil',
#   'numérique',
#   'leader',
#   'domaine',
#   'technologie',
#   'information',
#   'communication',
#   'système',
#   'information',
#   'e',
#   'solution',
#   'accompagner',
#   'transformation',
#   'digital',
#   'client',
#   'phase',
#   'projet',
#   'appel',
#   'expert',
#   'véritable',
#   'partenaire',
#   'technologique',
#   'e',
#   'solution',
#   'travailler',
#   'quotidien',
#   'satisfaire',
#   'client',
#   'facteur',
#   'cler',
#   'succès',
#   'innovation',
#   'engagement',
#   'excellence',
#   'qualité',
#   'être',
#   'guider',
#   'ensembl',
#   'valeur',
#   'fondamental',
#   'façonner',
#   'culture',
#   'assurer',
#   'succès',
#   'croire',
#   'innovation',
#   'durabilité',
#   'collaboration',
#   'œuvrer',
#   'mission',
#   'révolutionner',
#   'industrie',
#   'technologie',
#   'information',
#   'e',
#   'solution',
#   'engager',
#   'intégrité',
#   'centricité',
#   'client',
#   'excellence',
#   'entreprendre',
#   'équipe',
#   'passionner',
#   'volonté',
#   'créer',
#   'impact',
#   'positif',
#   'secteur',
#   'technologie',
#   'information',
#   'rejoindre',
#   'nous',
#   'e',
#   'solution',
#   'contribuer',
#   'façonner',
#   'avenir',
#   'industrie',
#   'technologie',
#   'information',
#   'ensemble',
#   'pouvoir',
#   'repousser',
#   'limite',
#   'innovation',
#   'créer',
#   'impact',
#   'positif',
#   'client',
#   'employer',
#   'poste',
#   'responsabilité',
#   'hiérarchique',
#   'chef',
#   'projet',
#   'intervenir',
#   'développeur',
#   'full',
#   'stack',
#   'php',
#   'mission',
#   'assurer',
#   'maintenance',
#   'correctif',
#   'évolutif',
#   'application',
#   'php',
#   'assurer',
#   'développement',
#   'complexe',
#   'capable',
#   'assimiler',
#   'améliorer',
#   'fonctionnalité',
#   'métier',
#   'complexe',
#   'analyser',
#   'besoin',
#   'exprimer',
#   'spécification',
#   'fonctionnel',
#   'travailler',
#   'méthode',
#   'agile',
#   'collaboration',
#   'responsable',
#   'fonctionnel',
#   'assurer',
#   'test',
#   'unitaire',
#   'intégration',
#   'jusqu',
#   "'",
#   'déploiement',
#   'garer',
#   'qualité',
#   'code',
#   'rédiger',
#   'documentation',
#   'technique',
#   'dossier',
#   'exploitation',
#   'profil',
#   'rechercher',
#   'compétence',
#   'technique',
#   'capacité',
#   'fournir',
#   'encadrement',
#   'technique',
#   'guider',
#   'membre',
#   'équipe',
#   'développement',
#   'connaissance',
#   'technique',
#   'linux',
#   'apache',
#   'mysql',
#   'sql',
#   'server',
#   'git',
#   'xml',
#   'web',
#   'service',
#   'superviseur',
#   'fort',
#   'capacité',
#   'communication',
#   'interaction',
#   'client',
#   'party',
#   'prendre',
#   'capacité',
#   'travailler',
#   'efficacement',
#   'pression',
#   'respecter',
#   'délai',
#   'bon',
#   'connaissance',
#   'design',
#   'pattern',
#   'capacité',
#   'analyse',
#   'conception',
#   'force',
#   'proposition',
#   'capacité',
#   'travailler',
#   'efficacement',
#   'pression',
#   'respecter',
#   'délai',
#   'implication',
#   'travail',
#   'besoin',
#   'autonomie',
#   'besoin',
#   'réflexion',
#   'ambition',
#   'recherche',
#   'nouveauté',
#   'implication',
#   'travail',
#   'besoin',
#   'autonomie',
#   'besoin',
#   'réflexion',
#   'ambition',
#   'recherche',
#   'nouveauté']]

# %%
def compare_simhashes(simhash1, simhash2):
    
    int_simhash1 = int(simhash1, 16)
    int_simhash2 = int(simhash2, 16)
  
    distance = bin(int_simhash1 ^ int_simhash2).count('1')
  
    return distance

# %%
jobs1_list = []
jobs2_list = []
distances = []
hast_str1 = []
hast_str2 = []
for i in range(len(fp_hast_str_list)):
    for j in range(len(fp_hast_str_list)):
        dist = compare_simhashes(fp_hast_str_list[i], fp_hast_str_list[j])
        distances.append(dist)
        similarty_matrix.loc[data_org['Title'][i], data_org['Title'][j]] = 1 - dist/128
        jobs1_list.append(data_trans[i]['Title'])
        hast_str1.append(fp_hast_str_list[i])
        jobs2_list.append(data_trans[j]['Title'])
        hast_str2.append(fp_hast_str_list[j])

# %%
jobs1_list_df=pd.DataFrame(jobs1_list,columns=['Job offer 1'])
jobs2_list_df=pd.DataFrame(jobs2_list,columns=['Job offer 2'])
hast_str1_df = pd.DataFrame(hast_str1,columns=['Simhash For Job offer 1'])
hast_str2_df = pd.DataFrame(hast_str2,columns=['Simhash For Job offer 2'])
distances_df = pd.DataFrame(distances,columns=['Distances'])

# %%
temp=[]
for i in range(len(distances)):

    if distances[i] < 10:
        temp.append(distances[i])

# %%
len(temp)
# Out:
# 1773

# %%
Simhash_Sim_df=pd.concat([jobs1_list_df,jobs2_list_df,hast_str1_df,hast_str2_df, distances_df],axis=1)
Simhash_Sim_df
# Out:
#                                                Job offer 1  \
# 0              développeur full stack php casablanca maroc
# 1              développeur full stack php casablanca maroc
# 2              développeur full stack php casablanca maroc
# 3              développeur full stack php casablanca maroc
# 4              développeur full stack php casablanca maroc
# ...                                                    ...
# 1515356  directeur qualité formation groupe call center...
# 1515357  directeur qualité formation groupe call center...
# 1515358  directeur qualité formation groupe call center...
# 1515359  directeur qualité formation groupe call center...
# 1515360  directeur qualité formation groupe call center...
#
#                                                Job offer 2  \
# 0              développeur full stack php casablanca maroc
# 1                            area manager casablanca maroc
# 2                     stagiaire marketing casablanca maroc
# 3        support it sénior plus 5 an expérience rabat m...
# 4                        agent logistique casablanca maroc
# ...                                                    ...
# 1515356  ingénieur étude développement java sénior heur...
# 1515357              ingénieur production casablanca maroc
# 1515358          ingénieur virtualisation casablanca maroc
# 1515359                  stagiaire recrutement rabat maroc
# 1515360  directeur qualité formation groupe call center...
#
#                                    Simhash For Job offer 1  \
# 0        1110110111101011100001010110101000001110000001...
# 1        1110110111101011100001010110101000001110000001...
# 2        1110110111101011100001010110101000001110000001...
# 3        1110110111101011100001010110101000001110000001...
# 4        1110110111101011100001010110101000001110000001...
# ...                                                    ...
# 1515356  1111011101001000110011010100100110001101000000...
# 1515357  1111011101001000110011010100100110001101000000...
# 1515358  1111011101001000110011010100100110001101000000...
# 1515359  1111011101001000110011010100100110001101000000...
# 1515360  1111011101001000110011010100100110001101000000...
#
#                                    Simhash For Job offer 2  Distances
# 0        1110110111101011100001010110101000001110000001...          0
# 1        1100011010001011010100010101111010101101000010...         56
# 2        1101011011001001110001010010110000100101000000...         59
# 3        1111001111101000100010010101111010001100000001...         45
# 4        1101000010011000010010010000110010101100000101...         54
# ...                                                    ...        ...
# 1515356  1010001101011011100111010000110100001101000000...         47
# 1515357  1111111101101001000010000110011100011100110011...         49
# 1515358  1010010101111010000010000110010110011100110000...         56
# 1515359  1111001011000011100111110100111010001100010000...         43
# 1515360  1111011101001000110011010100100110001101000000...          0
#
# [1515361 rows x 5 columns]

# %%
Simhash_Sim_df["Similarity"] = 1 - Simhash_Sim_df["Distances"]/128
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14308\41983818.py in <module>
# ----> 1 Simhash_Sim_df["Similarity"] = 1 - Simhash_Sim_df["Distances"]/68
#
# NameError: name 'Simhash_Sim_df' is not defined

# %%
Simhash_Sim_df

# %%
similar_df = Simhash_Sim_df[(Simhash_Sim_df['Distances'] < 10)]

# %%
similar_df
# Out:
#                                                Job offer 1  \
# 0              développeur full stack php casablanca maroc
# 1232                         area manager casablanca maroc
# 2464                  stagiaire marketing casablanca maroc
# 3696     support it sénior plus 5 an expérience rabat m...
# 4928                     agent logistique casablanca maroc
# ...                                                    ...
# 1510432  ingénieur étude développement java sénior heur...
# 1511664              ingénieur production casablanca maroc
# 1512896          ingénieur virtualisation casablanca maroc
# 1514128                  stagiaire recrutement rabat maroc
# 1515360  directeur qualité formation groupe call center...
#
#                                                Job offer 2  \
# 0              développeur full stack php casablanca maroc
# 1232                         area manager casablanca maroc
# 2464                  stagiaire marketing casablanca maroc
# 3696     support it sénior plus 5 an expérience rabat m...
# 4928                     agent logistique casablanca maroc
# ...                                                    ...
# 1510432  ingénieur étude développement java sénior heur...
# 1511664              ingénieur production casablanca maroc
# 1512896          ingénieur virtualisation casablanca maroc
# 1514128                  stagiaire recrutement rabat maroc
# 1515360  directeur qualité formation groupe call center...
#
#                                    Simhash For Job offer 1  \
# 0        1110110111101011100001010110101000001110000001...
# 1232     1100011010001011010100010101111010101101000010...
# 2464     1101011011001001110001010010110000100101000000...
# 3696     1111001111101000100010010101111010001100000001...
# 4928     1101000010011000010010010000110010101100000101...
# ...                                                    ...
# 1510432  1010001101011011100111010000110100001101000000...
# 1511664  1111111101101001000010000110011100011100110011...
# 1512896  1010010101111010000010000110010110011100110000...
# 1514128  1111001011000011100111110100111010001100010000...
# 1515360  1111011101001000110011010100100110001101000000...
#
#                                    Simhash For Job offer 2  Distances  \
# 0        1110110111101011100001010110101000001110000001...          0
# 1232     1100011010001011010100010101111010101101000010...          0
# 2464     1101011011001001110001010010110000100101000000...          0
# 3696     1111001111101000100010010101111010001100000001...          0
# 4928     1101000010011000010010010000110010101100000101...          0
# ...                                                    ...        ...
# 1510432  1010001101011011100111010000110100001101000000...          0
# 1511664  1111111101101001000010000110011100011100110011...          0
# 1512896  1010010101111010000010000110010110011100110000...          0
# 1514128  1111001011000011100111110100111010001100010000...          0
# 1515360  1111011101001000110011010100100110001101000000...          0
#
#          Similarity
# 0               1.0
# 1232            1.0
# 2464            1.0
# 3696            1.0
# 4928            1.0
# ...             ...
# 1510432         1.0
# 1511664         1.0
# 1512896         1.0
# 1514128         1.0
# 1515360         1.0
#
# [1773 rows x 6 columns]

# %%
similarty_matrix = pd.DataFrame(similarty_matrix.fillna(0))
similarty_matrix
# Out:
#                                                     Développeur Full Stack PHP | Casablanca (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                            1.000000
# AREA MANAGER | CASABLANCA (Maroc)                                                          0.562500
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                                0.539062
# Support IT sénior ( +5 ans d'expérience) | Raba...                                         0.648438
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                                      0.578125
# ...                                                                                             ...
# Ingénieur études et développement JAVA Sénior (...                                         0.578125
# Ingénieur de Production | Casablanca (Maroc)                                               0.671875
# Ingénieur Virtualisation | Casablanca (Maroc)                                              0.617188
# Stagiaire Recrutement | Rabat (Maroc)                                                      0.562500
# Directeur Qualité Formation Groupe ( Call cente...                                         0.632812
#
#                                                     AREA MANAGER | CASABLANCA (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                              0.562500
# AREA MANAGER | CASABLANCA (Maroc)                                            1.000000
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                  0.664062
# Support IT sénior ( +5 ans d'expérience) | Raba...                           0.601562
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                        0.687500
# ...                                                                               ...
# Ingénieur études et développement JAVA Sénior (...                           0.531250
# Ingénieur de Production | Casablanca (Maroc)                                 0.531250
# Ingénieur Virtualisation | Casablanca (Maroc)                                0.539062
# Stagiaire Recrutement | Rabat (Maroc)                                        0.609375
# Directeur Qualité Formation Groupe ( Call cente...                           0.554688
#
#                                                     STAGIAIRE EN MARKETING | CASABLANCA (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                        0.539062
# AREA MANAGER | CASABLANCA (Maroc)                                                      0.664062
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                            1.000000
# Support IT sénior ( +5 ans d'expérience) | Raba...                                     0.546875
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                                  0.632812
# ...                                                                                         ...
# Ingénieur études et développement JAVA Sénior (...                                     0.554688
# Ingénieur de Production | Casablanca (Maroc)                                           0.414062
# Ingénieur Virtualisation | Casablanca (Maroc)                                          0.421875
# Stagiaire Recrutement | Rabat (Maroc)                                                  0.648438
# Directeur Qualité Formation Groupe ( Call cente...                                     0.593750
#
#                                                     Support IT sénior ( +5 ans d'expérience) | Rabat (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                              0.648438
# AREA MANAGER | CASABLANCA (Maroc)                                                            0.601562
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                                  0.546875
# Support IT sénior ( +5 ans d'expérience) | Raba...                                           1.000000
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                                        0.617188
# ...                                                                                               ...
# Ingénieur études et développement JAVA Sénior (...                                           0.539062
# Ingénieur de Production | Casablanca (Maroc)                                                 0.539062
# Ingénieur Virtualisation | Casablanca (Maroc)                                                0.593750
# Stagiaire Recrutement | Rabat (Maroc)                                                        0.679688
# Directeur Qualité Formation Groupe ( Call cente...                                           0.656250
#
#                                                     AGENT LOGISTIQUE | CASABLANCA (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                  0.578125
# AREA MANAGER | CASABLANCA (Maroc)                                                0.687500
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                      0.632812
# Support IT sénior ( +5 ans d'expérience) | Raba...                               0.617188
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                            1.000000
# ...                                                                                   ...
# Ingénieur études et développement JAVA Sénior (...                               0.515625
# Ingénieur de Production | Casablanca (Maroc)                                     0.515625
# Ingénieur Virtualisation | Casablanca (Maroc)                                    0.570312
# Stagiaire Recrutement | Rabat (Maroc)                                            0.578125
# Directeur Qualité Formation Groupe ( Call cente...                               0.601562
#
#                                                     Devenez Consultant en rejoignant Leyton ! (Offre ouvertes aux ingénieurs, docteurs et doctorants en informatique) | Casablanca (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                              0.609375
# AREA MANAGER | CASABLANCA (Maroc)                                                            0.546875
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                                  0.539062
# Support IT sénior ( +5 ans d'expérience) | Raba...                                           0.523438
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                                        0.546875
# ...                                                                                               ...
# Ingénieur études et développement JAVA Sénior (...                                           0.593750
# Ingénieur de Production | Casablanca (Maroc)                                                 0.640625
# Ingénieur Virtualisation | Casablanca (Maroc)                                                0.664062
# Stagiaire Recrutement | Rabat (Maroc)                                                        0.562500
# Directeur Qualité Formation Groupe ( Call cente...                                           0.617188
#
#                                                     Expert.e en Finance Digital (FinTech) | Rabat (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                              0.539062
# AREA MANAGER | CASABLANCA (Maroc)                                                            0.585938
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                                  0.609375
# Support IT sénior ( +5 ans d'expérience) | Raba...                                           0.578125
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                                        0.601562
# ...                                                                                               ...
# Ingénieur études et développement JAVA Sénior (...                                           0.601562
# Ingénieur de Production | Casablanca (Maroc)                                                 0.507812
# Ingénieur Virtualisation | Casablanca (Maroc)                                                0.546875
# Stagiaire Recrutement | Rabat (Maroc)                                                        0.554688
# Directeur Qualité Formation Groupe ( Call cente...                                           0.703125
#
#                                                     Responsable Magasin | Kenitra (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                  0.585938
# AREA MANAGER | CASABLANCA (Maroc)                                                0.789062
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                      0.687500
# Support IT sénior ( +5 ans d'expérience) | Raba...                               0.546875
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                            0.742188
# ...                                                                                   ...
# Ingénieur études et développement JAVA Sénior (...                               0.554688
# Ingénieur de Production | Casablanca (Maroc)                                     0.554688
# Ingénieur Virtualisation | Casablanca (Maroc)                                    0.531250
# Stagiaire Recrutement | Rabat (Maroc)                                            0.601562
# Directeur Qualité Formation Groupe ( Call cente...                               0.656250
#
#                                                     Comptable H/F | Casablanca (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                               0.578125
# AREA MANAGER | CASABLANCA (Maroc)                                             0.593750
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                   0.617188
# Support IT sénior ( +5 ans d'expérience) | Raba...                            0.539062
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                         0.640625
# ...                                                                                ...
# Ingénieur études et développement JAVA Sénior (...                            0.578125
# Ingénieur de Production | Casablanca (Maroc)                                  0.546875
# Ingénieur Virtualisation | Casablanca (Maroc)                                 0.507812
# Stagiaire Recrutement | Rabat (Maroc)                                         0.562500
# Directeur Qualité Formation Groupe ( Call cente...                            0.664062
#
#                                                     Développeur Fullstack PHP Laravel (Freelance ou CDI) | Casablanca (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                              0.640625
# AREA MANAGER | CASABLANCA (Maroc)                                                            0.500000
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                                  0.554688
# Support IT sénior ( +5 ans d'expérience) | Raba...                                           0.648438
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                                        0.609375
# ...                                                                                               ...
# Ingénieur études et développement JAVA Sénior (...                                           0.593750
# Ingénieur de Production | Casablanca (Maroc)                                                 0.625000
# Ingénieur Virtualisation | Casablanca (Maroc)                                                0.632812
# Stagiaire Recrutement | Rabat (Maroc)                                                        0.609375
# Directeur Qualité Formation Groupe ( Call cente...                                           0.648438
#
#                                                     ...  \
# Développeur Full Stack PHP | Casablanca (Maroc)     ...
# AREA MANAGER | CASABLANCA (Maroc)                   ...
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)         ...
# Support IT sénior ( +5 ans d'expérience) | Raba...  ...
# AGENT LOGISTIQUE | CASABLANCA (Maroc)               ...
# ...                                                 ...
# Ingénieur études et développement JAVA Sénior (...  ...
# Ingénieur de Production | Casablanca (Maroc)        ...
# Ingénieur Virtualisation | Casablanca (Maroc)       ...
# Stagiaire Recrutement | Rabat (Maroc)               ...
# Directeur Qualité Formation Groupe ( Call cente...  ...
#
#                                                     Administrateur Système SharePoint et O365 avancés | Technopolis (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                              0.609375
# AREA MANAGER | CASABLANCA (Maroc)                                                            0.546875
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                                  0.570312
# Support IT sénior ( +5 ans d'expérience) | Raba...                                           0.617188
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                                        0.593750
# ...                                                                                               ...
# Ingénieur études et développement JAVA Sénior (...                                           0.546875
# Ingénieur de Production | Casablanca (Maroc)                                                 0.500000
# Ingénieur Virtualisation | Casablanca (Maroc)                                                0.554688
# Stagiaire Recrutement | Rabat (Maroc)                                                        0.562500
# Directeur Qualité Formation Groupe ( Call cente...                                           0.585938
#
#                                                     Chargé(e) de Communication | Salé (Technopolis) (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                              0.593750
# AREA MANAGER | CASABLANCA (Maroc)                                                            0.546875
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                                  0.539062
# Support IT sénior ( +5 ans d'expérience) | Raba...                                           0.632812
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                                        0.593750
# ...                                                                                               ...
# Ingénieur études et développement JAVA Sénior (...                                           0.546875
# Ingénieur de Production | Casablanca (Maroc)                                                 0.500000
# Ingénieur Virtualisation | Casablanca (Maroc)                                                0.585938
# Stagiaire Recrutement | Rabat (Maroc)                                                        0.625000
# Directeur Qualité Formation Groupe ( Call cente...                                           0.617188
#
#                                                     Full stack PHP/Javascript senior 5 ans d'expérience ( full remote) | Casablanca (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                              0.726562
# AREA MANAGER | CASABLANCA (Maroc)                                                            0.632812
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                                  0.546875
# Support IT sénior ( +5 ans d'expérience) | Raba...                                           0.781250
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                                        0.570312
# ...                                                                                               ...
# Ingénieur études et développement JAVA Sénior (...                                           0.617188
# Ingénieur de Production | Casablanca (Maroc)                                                 0.601562
# Ingénieur Virtualisation | Casablanca (Maroc)                                                0.546875
# Stagiaire Recrutement | Rabat (Maroc)                                                        0.632812
# Directeur Qualité Formation Groupe ( Call cente...                                           0.640625
#
#                                                     Ingénieur études et développement JAVA Confirmé (H/F) | Tanger/ Tétouan (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                              0.609375
# AREA MANAGER | CASABLANCA (Maroc)                                                            0.546875
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                                  0.570312
# Support IT sénior ( +5 ans d'expérience) | Raba...                                           0.554688
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                                        0.546875
# ...                                                                                               ...
# Ingénieur études et développement JAVA Sénior (...                                           0.937500
# Ingénieur de Production | Casablanca (Maroc)                                                 0.609375
# Ingénieur Virtualisation | Casablanca (Maroc)                                                0.664062
# Stagiaire Recrutement | Rabat (Maroc)                                                        0.593750
# Directeur Qualité Formation Groupe ( Call cente...                                           0.648438
#
#                                                     Développeur PHP | Rabat (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                            0.664062
# AREA MANAGER | CASABLANCA (Maroc)                                          0.554688
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                0.625000
# Support IT sénior ( +5 ans d'expérience) | Raba...                         0.593750
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                      0.585938
# ...                                                                             ...
# Ingénieur études et développement JAVA Sénior (...                         0.601562
# Ingénieur de Production | Casablanca (Maroc)                               0.570312
# Ingénieur Virtualisation | Casablanca (Maroc)                              0.546875
# Stagiaire Recrutement | Rabat (Maroc)                                      0.617188
# Directeur Qualité Formation Groupe ( Call cente...                         0.578125
#
#                                                     Ingénieur études et développement JAVA Sénior (H/F) | Tanger/ Tétouan (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                              0.578125
# AREA MANAGER | CASABLANCA (Maroc)                                                            0.531250
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                                  0.554688
# Support IT sénior ( +5 ans d'expérience) | Raba...                                           0.539062
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                                        0.515625
# ...                                                                                               ...
# Ingénieur études et développement JAVA Sénior (...                                           1.000000
# Ingénieur de Production | Casablanca (Maroc)                                                 0.609375
# Ingénieur Virtualisation | Casablanca (Maroc)                                                0.648438
# Stagiaire Recrutement | Rabat (Maroc)                                                        0.593750
# Directeur Qualité Formation Groupe ( Call cente...                                           0.632812
#
#                                                     Ingénieur de Production | Casablanca (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                         0.671875
# AREA MANAGER | CASABLANCA (Maroc)                                                       0.531250
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                             0.414062
# Support IT sénior ( +5 ans d'expérience) | Raba...                                      0.539062
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                                   0.515625
# ...                                                                                          ...
# Ingénieur études et développement JAVA Sénior (...                                      0.609375
# Ingénieur de Production | Casablanca (Maroc)                                            1.000000
# Ingénieur Virtualisation | Casablanca (Maroc)                                           0.710938
# Stagiaire Recrutement | Rabat (Maroc)                                                   0.531250
# Directeur Qualité Formation Groupe ( Call cente...                                      0.617188
#
#                                                     Ingénieur Virtualisation | Casablanca (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                          0.617188
# AREA MANAGER | CASABLANCA (Maroc)                                                        0.539062
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                              0.421875
# Support IT sénior ( +5 ans d'expérience) | Raba...                                       0.593750
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                                    0.570312
# ...                                                                                           ...
# Ingénieur études et développement JAVA Sénior (...                                       0.648438
# Ingénieur de Production | Casablanca (Maroc)                                             0.710938
# Ingénieur Virtualisation | Casablanca (Maroc)                                            1.000000
# Stagiaire Recrutement | Rabat (Maroc)                                                    0.492188
# Directeur Qualité Formation Groupe ( Call cente...                                       0.562500
#
#                                                     Stagiaire Recrutement | Rabat (Maroc)  \
# Développeur Full Stack PHP | Casablanca (Maroc)                                  0.562500
# AREA MANAGER | CASABLANCA (Maroc)                                                0.609375
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                      0.648438
# Support IT sénior ( +5 ans d'expérience) | Raba...                               0.679688
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                            0.578125
# ...                                                                                   ...
# Ingénieur études et développement JAVA Sénior (...                               0.593750
# Ingénieur de Production | Casablanca (Maroc)                                     0.531250
# Ingénieur Virtualisation | Casablanca (Maroc)                                    0.492188
# Stagiaire Recrutement | Rabat (Maroc)                                            1.000000
# Directeur Qualité Formation Groupe ( Call cente...                               0.664062
#
#                                                     Directeur Qualité Formation Groupe ( Call center) | Casablanca (Maroc)
# Développeur Full Stack PHP | Casablanca (Maroc)                                              0.632812
# AREA MANAGER | CASABLANCA (Maroc)                                                            0.554688
# STAGIAIRE EN MARKETING | CASABLANCA (Maroc)                                                  0.593750
# Support IT sénior ( +5 ans d'expérience) | Raba...                                           0.656250
# AGENT LOGISTIQUE | CASABLANCA (Maroc)                                                        0.601562
# ...                                                                                               ...
# Ingénieur études et développement JAVA Sénior (...                                           0.632812
# Ingénieur de Production | Casablanca (Maroc)                                                 0.617188
# Ingénieur Virtualisation | Casablanca (Maroc)                                                0.562500
# Stagiaire Recrutement | Rabat (Maroc)                                                        0.664062
# Directeur Qualité Formation Groupe ( Call cente...                                           1.000000
#
# [1231 rows x 1231 columns]

# %%
similarty_matrix.to_csv("Simhash_similarity_matrix.csv", mode = 'w', index=False)

# %%
Simhash_Sim_df.to_csv("Simhash_similarity.csv", mode = 'w', index=False)

# %%
simhash = pd.read_csv("Simhash_similarity.csv")

# %%
simhash["Similarity"] = 1 - simhash["Distances"]/64

# %%
simhash.to_csv("Simhash_similarity.csv", mode = 'w', index=False)
